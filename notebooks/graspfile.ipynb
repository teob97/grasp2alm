# %%
import graspfile.cut
import matplotlib.pyplot as plt

# %%
cut_beam = graspfile.cut.GraspCut()
file_cut = open("spherical_cut.cut", 'r')

# %%
cut_beam.read(file_cut)

# %%
plt.plot(cut_beam.cut_sets[0].cuts[2].data)
